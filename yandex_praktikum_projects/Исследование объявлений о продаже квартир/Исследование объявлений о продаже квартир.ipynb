# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Обработка-&quot;total_images&quot;" data-toc-modified-id="1.-Обработка-&quot;total_images&quot;-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>1. Обработка "total_images"</a></span></li><li><span><a href="#2.-Обработка-&quot;last_price&quot;" data-toc-modified-id="2.-Обработка-&quot;last_price&quot;-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>2. Обработка "last_price"</a></span></li><li><span><a href="#3.-Обработка-&quot;total_area&quot;" data-toc-modified-id="3.-Обработка-&quot;total_area&quot;-2.0.3"><span class="toc-item-num">2.0.3&nbsp;&nbsp;</span>3. Обработка "total_area"</a></span></li><li><span><a href="#4.-Обработка-&quot;first_day_exposition&quot;" data-toc-modified-id="4.-Обработка-&quot;first_day_exposition&quot;-2.0.4"><span class="toc-item-num">2.0.4&nbsp;&nbsp;</span>4. Обработка "first_day_exposition"</a></span></li><li><span><a href="#5.-Обработка-&quot;rooms&quot;" data-toc-modified-id="5.-Обработка-&quot;rooms&quot;-2.0.5"><span class="toc-item-num">2.0.5&nbsp;&nbsp;</span>5. Обработка "rooms"</a></span></li><li><span><a href="#6.-Обработка-&quot;ceiling_height&quot;" data-toc-modified-id="6.-Обработка-&quot;ceiling_height&quot;-2.0.6"><span class="toc-item-num">2.0.6&nbsp;&nbsp;</span>6. Обработка "ceiling_height"</a></span></li><li><span><a href="#7.-Обработка-&quot;floors_total&quot;" data-toc-modified-id="7.-Обработка-&quot;floors_total&quot;-2.0.7"><span class="toc-item-num">2.0.7&nbsp;&nbsp;</span>7. Обработка "floors_total"</a></span></li><li><span><a href="#8.-Обработка-&quot;living_area&quot;" data-toc-modified-id="8.-Обработка-&quot;living_area&quot;-2.0.8"><span class="toc-item-num">2.0.8&nbsp;&nbsp;</span>8. Обработка "living_area"</a></span></li><li><span><a href="#9.-Обработка-&quot;floor&quot;" data-toc-modified-id="9.-Обработка-&quot;floor&quot;-2.0.9"><span class="toc-item-num">2.0.9&nbsp;&nbsp;</span>9. Обработка "floor"</a></span></li><li><span><a href="#10.-Обработка-&quot;is_apartment&quot;" data-toc-modified-id="10.-Обработка-&quot;is_apartment&quot;-2.0.10"><span class="toc-item-num">2.0.10&nbsp;&nbsp;</span>10. Обработка "is_apartment"</a></span></li><li><span><a href="#11.-Обработка-&quot;studio&quot;" data-toc-modified-id="11.-Обработка-&quot;studio&quot;-2.0.11"><span class="toc-item-num">2.0.11&nbsp;&nbsp;</span>11. Обработка "studio"</a></span></li><li><span><a href="#12.-Обработка-&quot;open_plan&quot;" data-toc-modified-id="12.-Обработка-&quot;open_plan&quot;-2.0.12"><span class="toc-item-num">2.0.12&nbsp;&nbsp;</span>12. Обработка "open_plan"</a></span></li><li><span><a href="#13.-Обработка-&quot;kitchen_area&quot;" data-toc-modified-id="13.-Обработка-&quot;kitchen_area&quot;-2.0.13"><span class="toc-item-num">2.0.13&nbsp;&nbsp;</span>13. Обработка "kitchen_area"</a></span></li><li><span><a href="#14.-Обработка-&quot;balcony&quot;" data-toc-modified-id="14.-Обработка-&quot;balcony&quot;-2.0.14"><span class="toc-item-num">2.0.14&nbsp;&nbsp;</span>14. Обработка "balcony"</a></span></li><li><span><a href="#15.-Обработка-&quot;locality_name&quot;" data-toc-modified-id="15.-Обработка-&quot;locality_name&quot;-2.0.15"><span class="toc-item-num">2.0.15&nbsp;&nbsp;</span>15. Обработка "locality_name"</a></span></li><li><span><a href="#16.-Обработка-&quot;airports_nearest&quot;" data-toc-modified-id="16.-Обработка-&quot;airports_nearest&quot;-2.0.16"><span class="toc-item-num">2.0.16&nbsp;&nbsp;</span>16. Обработка "airports_nearest"</a></span></li><li><span><a href="#17.-Обработка-&quot;cityCenters_nearest&quot;" data-toc-modified-id="17.-Обработка-&quot;cityCenters_nearest&quot;-2.0.17"><span class="toc-item-num">2.0.17&nbsp;&nbsp;</span>17. Обработка "cityCenters_nearest"</a></span></li><li><span><a href="#18.-Обработка-&quot;parks_around3000&quot;" data-toc-modified-id="18.-Обработка-&quot;parks_around3000&quot;-2.0.18"><span class="toc-item-num">2.0.18&nbsp;&nbsp;</span>18. Обработка "parks_around3000"</a></span></li><li><span><a href="#19.-Обработка-&quot;parks_nearest&quot;" data-toc-modified-id="19.-Обработка-&quot;parks_nearest&quot;-2.0.19"><span class="toc-item-num">2.0.19&nbsp;&nbsp;</span>19. Обработка "parks_nearest"</a></span></li><li><span><a href="#20.-Обработка-&quot;ponds_around3000&quot;" data-toc-modified-id="20.-Обработка-&quot;ponds_around3000&quot;-2.0.20"><span class="toc-item-num">2.0.20&nbsp;&nbsp;</span>20. Обработка "ponds_around3000"</a></span></li><li><span><a href="#21.-Обработка-&quot;ponds_nearest&quot;" data-toc-modified-id="21.-Обработка-&quot;ponds_nearest&quot;-2.0.21"><span class="toc-item-num">2.0.21&nbsp;&nbsp;</span>21. Обработка "ponds_nearest"</a></span></li><li><span><a href="#22.-Обработка-&quot;days_exposition&quot;" data-toc-modified-id="22.-Обработка-&quot;days_exposition&quot;-2.0.22"><span class="toc-item-num">2.0.22&nbsp;&nbsp;</span>22. Обработка "days_exposition"</a></span></li></ul></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Гистограммы-значений-total_area,--last_price,-rooms-и-ceiling_height" data-toc-modified-id="Гистограммы-значений-total_area,--last_price,-rooms-и-ceiling_height-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Гистограммы значений total_area,  last_price, rooms и ceiling_height</a></span><ul class="toc-item"><li><span><a href="#Площадь" data-toc-modified-id="Площадь-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Площадь</a></span></li><li><span><a href="#Стоимость-квартиры" data-toc-modified-id="Стоимость-квартиры-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Стоимость квартиры</a></span></li><li><span><a href="#Количество-комнат" data-toc-modified-id="Количество-комнат-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Количество комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Высота потолков</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Вывод:</a></span></li></ul></li><li><span><a href="#Исследование-времени-продажи-квартиры" data-toc-modified-id="Исследование-времени-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Исследование времени продажи квартиры</a></span></li><li><span><a href="#Удаление-аномальных-значений" data-toc-modified-id="Удаление-аномальных-значений-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Удаление аномальных значений</a></span><ul class="toc-item"><li><span><a href="#Аномалии-в-days_exposition" data-toc-modified-id="Аномалии-в-days_exposition-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Аномалии в days_exposition</a></span></li><li><span><a href="#Отфильтрую-другие-аномальные-значения." data-toc-modified-id="Отфильтрую-другие-аномальные-значения.-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Отфильтрую другие аномальные значения.</a></span></li></ul></li><li><span><a href="#Зависимость-цена-квадратного-метра-от-различных-значений." data-toc-modified-id="Зависимость-цена-квадратного-метра-от-различных-значений.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Зависимость цена квадратного метра от различных значений.</a></span><ul class="toc-item"><li><span><a href="#От-общей-площади-квартиры." data-toc-modified-id="От-общей-площади-квартиры.-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>От общей площади квартиры.</a></span></li><li><span><a href="#От-числа-комнат" data-toc-modified-id="От-числа-комнат-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>От числа комнат</a></span></li><li><span><a href="#От-этажа" data-toc-modified-id="От-этажа-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>От этажа</a></span></li><li><span><a href="#От-удалённости-от-центра" data-toc-modified-id="От-удалённости-от-центра-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>От удалённости от центра</a></span></li><li><span><a href="#От-дня-недели,-месяца,-года." data-toc-modified-id="От-дня-недели,-месяца,-года.-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>От дня недели, месяца, года.</a></span></li></ul></li><li><span><a href="#Исследование-населённых-пунктов" data-toc-modified-id="Исследование-населённых-пунктов-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Исследование населённых пунктов</a></span><ul class="toc-item"><li><span><a href="#Сравним-значения-с-исходными-данными-(без-фильтрации-по-дате)." data-toc-modified-id="Сравним-значения-с-исходными-данными-(без-фильтрации-по-дате).-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Сравним значения с исходными данными (без фильтрации по дате).</a></span></li></ul></li><li><span><a href="#Зависимость-Стоимости-жилья-в-Санкт-Петербурге-от-расстояния-до-центра." data-toc-modified-id="Зависимость-Стоимости-жилья-в-Санкт-Петербурге-от-расстояния-до-центра.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Зависимость Стоимости жилья в Санкт-Петербурге от расстояния до центра.</a></span></li><li><span><a href="#Центр-Санкт-Петербурга" data-toc-modified-id="Центр-Санкт-Петербурга-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Центр Санкт-Петербурга</a></span><ul class="toc-item"><li><span><a href="#Зависимость-от-количества-комнат." data-toc-modified-id="Зависимость-от-количества-комнат.-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Зависимость от количества комнат.</a></span></li><li><span><a href="#Зависимость-от-этажа" data-toc-modified-id="Зависимость-от-этажа-4.7.2"><span class="toc-item-num">4.7.2&nbsp;&nbsp;</span>Зависимость от этажа</a></span></li><li><span><a href="#Зависимость-от-удаленности-от-центра." data-toc-modified-id="Зависимость-от-удаленности-от-центра.-4.7.3"><span class="toc-item-num">4.7.3&nbsp;&nbsp;</span>Зависимость от удаленности от центра.</a></span></li><li><span><a href="#Зависимость-от-дня-недели" data-toc-modified-id="Зависимость-от-дня-недели-4.7.4"><span class="toc-item-num">4.7.4&nbsp;&nbsp;</span>Зависимость от дня недели</a></span></li><li><span><a href="#Зависимость-от-месяца" data-toc-modified-id="Зависимость-от-месяца-4.7.5"><span class="toc-item-num">4.7.5&nbsp;&nbsp;</span>Зависимость от месяца</a></span></li><li><span><a href="#Зависимость-от-года" data-toc-modified-id="Зависимость-от-года-4.7.6"><span class="toc-item-num">4.7.6&nbsp;&nbsp;</span>Зависимость от года</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
#
#  **Цель исследования**:
# 1. Определить рыночную стоимость жилья.
# 2. Узнать какие факторы влияют на стоимость квартир.
#
# **Ход исследования**
#
#  1. Обзор данных.
#  2. Предобработка данных, которая включает:
#  * проверка на пропуски, ошибки и аномалии
#  * привидение к правильном формату.
#  3. Добавление новых значений:
#  * цена квадратного метра;
#  * день недели, месяц и год публикации объявления;
#  * этаж квартиры; варианты — первый, последний, другой;
#  * соотношение жилой и общей площади, а также отношение площади кухни к общей.
#  4. Проведение исследования:
#  * Изучить следующие параметры: площадь, цена, число комнат, высота потолков.
#  * Изучить время продажи квартиры.
#  * Изучить зависимость цены от площади, числа комнат, удалённости от центра, этажа и даты размещения.
#  * Выберать 10 населённых пунктов с наибольшим числом объявлений. Изучить населённые пункты с самой высокой и низкой стоимостью жилья.
#  * Изичуть стоимость квартир в Санкт-Петербурге, узнать зависимость цены от удалённости от центра, выделить центр города.
#  * Проанализировать квартиры в центре Санкт-Петербурга и сравнить со всей выборкой.
#  5. Общий вывод.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
from textwrap import dedent
from IPython import get_ipython
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import ast

# %%
pd.options.display.float_format = '{: .2f}'.format

# %%
try:
    df = pd.read_csv('real_estate_data.csv', sep='\t')#здесь указывается локальный путь

except:
    df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')# чтение файла из общего доступа
    
df.sample(5).T #колонок много - использую метод .T
# Out:
#                                     4799                 6040   \
# total_images                           12                   20
# last_price                     7000000.00           5650000.00
# total_area                          52.00                52.40
# first_day_exposition  2016-04-26T00:00:00  2018-08-16T00:00:00
# rooms                                   2                    2
# ceiling_height                        NaN                 2.67
# floors_total                         5.00                12.00
# living_area                         37.00                28.60
# floor                                   5                   11
# is_apartment                          NaN                  NaN
# studio                              False                False
# open_plan                           False                False
# kitchen_area                          NaN                 8.50
# balcony                              0.00                 2.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
df.describe().T
# Out:
#                         count        mean          std       min         25%  \
# total_images         23699.00        9.86         5.68      0.00        6.00
# last_price           23699.00  6541548.77  10887013.27  12190.00  3400000.00
# total_area           23699.00       60.35        35.65     12.00       40.00
# rooms                23699.00        2.07         1.08      0.00        1.00
# ceiling_height       14504.00        2.77         1.26      1.00        2.52
# floors_total         23613.00       10.67         6.60      1.00        5.00
# living_area          21796.00       34.46        22.03      2.00       18.60
# floor                23699.00        5.89         4.89      1.00        2.00
# kitchen_area         21421.00       10.57         5.91      1.30        7.00
# balcony              12180.00        1.15         1.07      0.00        0.00
# airports_nearest     18157.00    28793.67     12630.88      0.00    18585.00
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# В таблице видно много пропущенных значений, но на первый взгляд тут нет сильно забагованных значений, если смотреть на медиану, то значения в полнее реалестичны. В среднем выходит, что квартиры: двухкомнатные, c площадью 52 кв. м., с высотой потолков 2,65 м., в девятиэтажках, с жилой площадью 30 кв.м., с одним балконом и прудом по-близости.
# Посмотрим, что будет после предобработки. :)

# %% [markdown]
# ## Предобработка данных

# %%
# Код для удобного оформления предобработки.

# def create_cell(shell, text):
#     payload = dict(
#         source='set_next_input',
#         text=text,
#         replace=False,
#     )
#     shell.payload_manager.write_payload(payload, single=False)

# def column_preprocess_description(df):
#     shell = get_ipython()
#     for i, column in reversed(list(enumerate(df.columns))):
#         create_cell(shell, dedent(
#             '''
#             * Изменение
#             '''
#         ))
#         create_cell(shell, dedent(
#             '''
#             * Вывод
#             \t- Обнаруженные аномалии: ...
#             \t- Причины, по которым они могли возникнуть: ...
#             \t- Как исправлять: ...
#             \t- Финальный тип и почему: ...
#             '''
#         ))
#         create_cell(shell, dedent(
#             f'''
#             investigate_column(df["{column}"])
#             '''
#         ))
#         create_cell(shell, dedent(
#             '''
#             * Изучим значения
#             '''
#         ))
#         create_cell(shell, dedent(
#             f'''
#             #### {i+1}. Обработка "{column}"
#             '''
#         ))

# %%
def investigate_column(column):
    print('Null or Na count is', column.isna().sum())
    print(column.describe())

# %% [markdown]
# #### 1. Обработка "total_images"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["total_images"])
# Out:
# Null or Na count is 0
# count    23699.00
# mean         9.86
# std          5.68
# min          0.00
# 25%          6.00
# 50%          9.00
# 75%         14.00
# max         50.00
# Name: total_images, dtype: float64

# %%
df['total_images'].value_counts().sort_index()
# Out:
# 0     1059
# 1      872
# 2      640
# 3      769
# 4      986
# 5     1301
# 6     1482
# 7     1521
# 8     1585
# 9     1725
# 10    1798
# 11    1362
# 12    1225
# 13    1015
# 14     986
# 15     948
# 16     761
# 17     650
# 18     642
# 19     603
# 20    1694
# 21      12
# 22       8
# 23      16
# 24       8
# 25       1
# 26       5
# 27       2
# 28       4
# 29       3
# 30       2
# 31       2
# 32       4
# 35       2
# 37       1
# 39       1
# 42       1
# 50       3
# Name: total_images, dtype: int64

# %% [markdown]
# * Вывод
# 	- Аномалий не обнаружено, здесь всё в порядке. Возможно просто кто-то любит выложить поболше фоток )

# %% [markdown]
# #### 2. Обработка "last_price"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["last_price"])
# Out:
# Null or Na count is 0
# count        23699.00
# mean       6541548.77
# std       10887013.27
# min          12190.00
# 25%        3400000.00
# 50%        4650000.00
# 75%        6800000.00
# max      763000000.00
# Name: last_price, dtype: float64

# %%
df['last_price'].value_counts().sort_index()
# Out:
# 12190.00        1
# 430000.00       2
# 440000.00       1
# 450000.00       4
# 470000.00       3
#                ..
# 300000000.00    1
# 330000000.00    1
# 401300000.00    1
# 420000000.00    1
# 763000000.00    1
# Name: last_price, Length: 2978, dtype: int64

# %% [markdown]
# * Вывод
# 	- Аномалий не обнаружено, но тип изменю на int, потому что копейки нам не сильно актуальны и питон может не вполне адекватно выполнять с ними мат. действия, а лишние расхождения в финансах нам не  к чему.
#
# - Так же минимальное значение явно выбивается из общей массы, скорее всего оно аномальное. Возможно кто-то забыл добавить ноль (или даже не один).

# %% [markdown]
# * Изменение

# %%
df['last_price'] = df['last_price'].astype('int')

# %% [markdown]
# #### 3. Обработка "total_area"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["total_area"])
# Out:
# Null or Na count is 0
# count    23699.00
# mean        60.35
# std         35.65
# min         12.00
# 25%         40.00
# 50%         52.00
# 75%         69.90
# max        900.00
# Name: total_area, dtype: float64

# %%
df.total_area.sort_values()
# Out:
# 19904     12.00
# 17961     13.00
# 19546     13.00
# 19807     13.00
# 19558     13.20
#           ...
# 5358     590.00
# 15651    618.00
# 3117     631.00
# 12859    631.20
# 19540    900.00
# Name: total_area, Length: 23699, dtype: float64

# %%
df.total_area.value_counts().sort_index()
# Out:
# 12.00     1
# 13.00     3
# 13.20     1
# 14.00     1
# 15.00     2
#          ..
# 590.00    1
# 618.00    1
# 631.00    1
# 631.20    1
# 900.00    1
# Name: total_area, Length: 2182, dtype: int64

# %%
df.boxplot('total_area')
# Out:
# <AxesSubplot:>

# %%
df.query('total_area==900')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 19540             8   420000000      900.00  2017-12-06T00:00:00     12
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 19540            2.80         25.00       409.70     25          NaN  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 19540        112.00      NaN  Санкт-Петербург          30706.00
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 19540             7877.00              0.00            NaN              2.00
#
#        ponds_nearest  days_exposition
# 19540         318.00           106.00
#
# [1 rows x 22 columns]

# %%
df.query('total_area<=20').T
# Out:
#                                     716                  4077   \
# total_images                            5                   10
# last_price                        1500000              3000000
# total_area                          17.00                20.00
# first_day_exposition  2017-06-07T00:00:00  2017-04-10T00:00:00
# rooms                                   0                    2
# ceiling_height                       2.70                  NaN
# floors_total                         9.00                 6.00
# living_area                         12.00                13.00
# floor                                   1                    2
# is_apartment                          NaN                  NaN
# studio                               True                False
# open_plan                           False                False
# kitchen_area                          NaN                 5.60
# balcony                              0.00                 0.00
# ...

# %% [markdown]
# * Вывод
#     - Есть крайне высокое значение в 900 кв.м, но такая квартира вполне может быть, а возможно кто-то продаёт частный дом )
#     - присутсвует квартиры менее 20 кв.м., часть из них студии, это вполне логично. Возможно остальные так же относяться к этой категории, просто те кто выставлял обьявления забыли это указать. Либо данные указали неправильно, либо это и впрадва маленькие квартирки (самое странно тут видеть одну двухкомнатную). В любом случаее цена у большинства из них низкая, что вполне соотвуетсвует здравому смыслу.
#     - Число таких аномалий крайне мало, меньше чем 0,2%, поэтому можно их оставить как есть.

# %% [markdown]
# #### 4. Обработка "first_day_exposition"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["first_day_exposition"])
# Out:
# Null or Na count is 0
# count                   23699
# unique                   1491
# top       2018-02-01T00:00:00
# freq                      368
# Name: first_day_exposition, dtype: object

# %%
df["first_day_exposition"].value_counts()
# Out:
# 2018-02-01T00:00:00    368
# 2017-11-10T00:00:00    240
# 2017-10-13T00:00:00    124
# 2017-09-27T00:00:00    111
# 2018-03-26T00:00:00     97
#                       ...
# 2015-04-21T00:00:00      1
# 2015-06-01T00:00:00      1
# 2015-06-22T00:00:00      1
# 2015-09-19T00:00:00      1
# 2015-10-19T00:00:00      1
# Name: first_day_exposition, Length: 1491, dtype: int64

# %% [markdown]
# * Вывод
# 	- Обнаруженные аномалии: Это явно формат даты, а не int.
# 	- Как исправлять: поменять тип на datetime, указав только год-месяц-день, потому что время здесь не указано.

# %% [markdown]
# * Изменение

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format = '%Y-%m-%d')

# %% [markdown]
# #### 5. Обработка "rooms"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["rooms"])
# Out:
# Null or Na count is 0
# count    23699.00
# mean         2.07
# std          1.08
# min          0.00
# 25%          1.00
# 50%          2.00
# 75%          3.00
# max         19.00
# Name: rooms, dtype: float64

# %%
df["rooms"].value_counts().sort_index()
# Out:
# 0      197
# 1     8047
# 2     7940
# 3     5814
# 4     1180
# 5      326
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 12       1
# 14       2
# 15       1
# 16       1
# 19       1
# Name: rooms, dtype: int64

# %%
df.query('rooms>=10').T
# Out:
#                                     648                  866    \
# total_images                            3                    5
# last_price                       17500000             25000000
# total_area                         183.70               363.00
# first_day_exposition  2018-07-01 00:00:00  2017-12-23 00:00:00
# rooms                                  11                   14
# ceiling_height                       3.40                 3.16
# floors_total                         7.00                 5.00
# living_area                        138.80               222.00
# floor                                   7                    4
# is_apartment                          NaN                  NaN
# studio                              False                False
# open_plan                           False                False
# kitchen_area                        13.30                16.60
# balcony                               NaN                  NaN
# ...

# %% [markdown]
# * Вывод
# 	- Встречаються редкие значения число комнат больше 10.
#     - в целом стоимости таких квартир давольно высокие, так же как и площади.
#     - почти все они в центре/близко к центру города
#     - Такие обьявления вполне могут быть реальными, поэтому оставим их как есть.

# %% [markdown]
# #### 6. Обработка "ceiling_height"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["ceiling_height"])
# Out:
# Null or Na count is 9195
# count    14504.00
# mean         2.77
# std          1.26
# min          1.00
# 25%          2.52
# 50%          2.65
# 75%          2.80
# max        100.00
# Name: ceiling_height, dtype: float64

# %%
df["ceiling_height"].value_counts().sort_index()
# Out:
# 1.00       1
# 1.20       1
# 1.75       1
# 2.00      11
# 2.20       1
#           ..
# 26.00      1
# 27.00      8
# 27.50      1
# 32.00      2
# 100.00     1
# Name: ceiling_height, Length: 183, dtype: int64

# %%
df[df['ceiling_height'] > 4].sort_values('ceiling_height').sample(20)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 21923            10   115490000      235.00           2017-04-09      5
# 21824            20     2450000       44.00           2019-02-12      2
# 12628            14     3900000       50.00           2018-03-29      1
# 14619            15    16000000      100.00           2018-03-20      3
# 5807             17     8150000       80.00           2019-01-09      2
# 14382             9     1700000       35.00           2015-12-04      1
# 19142            10     8650000       87.70           2017-07-18      2
# 7274             16    43000000      280.00           2014-12-10      5
# 1300             14   120000000      280.00           2018-07-12      5
# 4201              9     8250000       84.20           2017-11-29      2
# 2823              8     2700000       39.00           2018-02-01      1
# 22494             7    91075000      491.00           2017-05-27      5
# ...

# %% [markdown]
# * Вывод
# 	- В целом серьёзных аномалий нет, но присутствует большое количество пропусков, скорее всего те, кто размещал обьявление просто не знал высоту потолков. Оставлю пропуски как есть. Так же присутсвует несколько экстремально больших-маленьких значений, но их очень мало, поэтому так же не буду трогать. Медиана не сильно отличаеться от средней из-за выбросов. Значения больше 10 самые подозрительные, возможно кто-то написал лишний ноль или перепутал графу?

# %% [markdown]
# #### 7. Обработка "floors_total"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["floors_total"])
# Out:
# Null or Na count is 86
# count    23613.00
# mean        10.67
# std          6.60
# min          1.00
# 25%          5.00
# 50%          9.00
# 75%         16.00
# max         60.00
# Name: floors_total, dtype: float64

# %%
df["floors_total"].value_counts().sort_index()
# Out:
# 1.00       25
# 2.00      383
# 3.00      668
# 4.00     1200
# 5.00     5788
# 6.00      914
# 7.00      592
# 8.00      390
# 9.00     3761
# 10.00    1174
# 11.00     203
# 12.00    1362
# 13.00     229
# 14.00     553
# 15.00     365
# 16.00    1376
# 17.00     833
# 18.00     505
# 19.00     339
# 20.00     271
# 21.00     158
# 22.00     286
# 23.00     352
# 24.00     469
# 25.00    1075
# 26.00     124
# 27.00     164
# 28.00      21
# 29.00       1
# 33.00       1
# 34.00       1
# 35.00      24
# 36.00       3
# 37.00       1
# 52.00       1
# 60.00       1
# Name: floors_total, dtype: int64

# %%
df[df['floors_total'].isna()].sample(15).T
# Out:
#                                     10058                3831   \
# total_images                            9                    5
# last_price                        3350000              4850000
# total_area                          25.00                37.40
# first_day_exposition  2018-09-10 00:00:00  2019-03-02 00:00:00
# rooms                                   1                    1
# ceiling_height                       2.65                  NaN
# floors_total                          NaN                  NaN
# living_area                         17.00                  NaN
# floor                                  21                    7
# is_apartment                          NaN                  NaN
# studio                              False                False
# open_plan                           False                False
# kitchen_area                         3.50                  NaN
# balcony                               NaN                  NaN
# ...

# %% [markdown]
# * Вывод
# 	- Обнаруженные аномалии: есть пропуски, но их не много, меньше половины процента.
# 	- Причины, по которым они могли возникнуть: возможно в обьявлениях не обязательно указывать общее количество этажей, вот кто-то и пропустил(забыл) про этот момент, при том что для покупателей он очень важен. )
# 	- Оставлю как есть.

# %% [markdown]
# #### 8. Обработка "living_area"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["living_area"])
# Out:
# Null or Na count is 1903
# count    21796.00
# mean        34.46
# std         22.03
# min          2.00
# 25%         18.60
# 50%         30.00
# 75%         42.30
# max        409.70
# Name: living_area, dtype: float64

# %%
df["living_area"].value_counts()
# Out:
# 18.00    882
# 17.00    675
# 30.00    598
# 16.00    486
# 20.00    481
#         ...
# 96.40      1
# 50.26      1
# 43.81      1
# 54.43      1
# 16.74      1
# Name: living_area, Length: 1782, dtype: int64

# %%
df["living_area"].hist(bins=50)
plt.xlabel('Жилая площадь')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# * Вывод
# 	- всё впорядке, есть пропуски, но скорее всего это значит, что жилая зона отсуствует, возможно в выборку попали обьявления с нежилыми помещениями, но стоит это уточнить это у заказчика.

# %% [markdown]
# #### 9. Обработка "floor"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["floor"])
# Out:
# Null or Na count is 0
# count    23699.00
# mean         5.89
# std          4.89
# min          1.00
# 25%          2.00
# 50%          4.00
# 75%          8.00
# max         33.00
# Name: floor, dtype: float64

# %%
df["floor"].value_counts()
# Out:
# 2     3368
# 3     3073
# 1     2917
# 4     2804
# 5     2621
# 6     1305
# 7     1218
# 8     1083
# 9     1051
# 10     687
# 12     526
# 11     523
# 13     379
# 15     343
# 14     337
# 16     315
# 17     227
# 18     178
# 19     147
# 21     125
# 22     113
# 20     110
# 23     100
# 24      63
# 25      46
# 26      24
# 27      10
# 28       1
# 29       1
# 32       1
# 30       1
# 33       1
# 31       1
# Name: floor, dtype: int64

# %% [markdown]
# * Вывод
# 	- Всё в порядке.

# %% [markdown]
# #### 10. Обработка "is_apartment"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["is_apartment"])
# Out:
# Null or Na count is 20924
# count      2775
# unique        2
# top       False
# freq       2725
# Name: is_apartment, dtype: object

# %%
df['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# * Вывод
# 	- Обнаруженные аномалии: Тип этого стобца должен быть bool и имеется огромное количество пропусков.
# 	- Причины, по которым они могли возникнуть: Вероятно учёт этой графы начали вести не сразу, поэтому заполнено так мало значений.
# 	- Как исправлять: заменить NaN на False. И поменять тип с int на bool.

# %% [markdown]
# * Изменение

# %%
df['is_apartment'] = df['is_apartment'].fillna(False)

# %%
df['is_apartment'] = df['is_apartment'].astype(bool)

# %% [markdown]
# #### 11. Обработка "studio"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["studio"])
# Out:
# Null or Na count is 0
# count     23699
# unique        2
# top       False
# freq      23550
# Name: studio, dtype: object

# %%
df["studio"].value_counts()
# Out:
# False    23550
# True       149
# Name: studio, dtype: int64

# %% [markdown]
# * Вывод
# 	- Всё в порядке.

# %% [markdown]
# * Изменение

# %% [markdown]
# #### 12. Обработка "open_plan"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["open_plan"])
# Out:
# Null or Na count is 0
# count     23699
# unique        2
# top       False
# freq      23632
# Name: open_plan, dtype: object

# %%
df["open_plan"].value_counts()
# Out:
# False    23632
# True        67
# Name: open_plan, dtype: int64

# %% [markdown]
# * Вывод
# 	- Всё в порядке.

# %% [markdown]
# #### 13. Обработка "kitchen_area"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["kitchen_area"])
# Out:
# Null or Na count is 2278
# count    21421.00
# mean        10.57
# std          5.91
# min          1.30
# 25%          7.00
# 50%          9.10
# 75%         12.00
# max        112.00
# Name: kitchen_area, dtype: float64

# %%
df["kitchen_area"].hist(bins=50)
plt.xlabel('Площадь кухни')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# * Вывод
# 	- Обнаруженные аномалии: всё в порядке. Есть выбросы, но их очень мало, так же как и домов с большой площадью.

# %% [markdown]
# #### 14. Обработка "balcony"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["balcony"])
# Out:
# Null or Na count is 11519
# count    12180.00
# mean         1.15
# std          1.07
# min          0.00
# 25%          0.00
# 50%          1.00
# 75%          2.00
# max          5.00
# Name: balcony, dtype: float64

# %%
df["balcony"].hist()
plt.xlabel('Площадь балкона')
plt.ylabel('Количество объявлений')
plt.show()

# %%
df['balcony'].value_counts().sort_index()
# Out:
# 0.00    3758
# 1.00    4195
# 2.00    3659
# 3.00      81
# 4.00     183
# 5.00     304
# Name: balcony, dtype: int64

# %% [markdown]
# * Вывод
# 	- Обнаруженные аномалии: Имеется много пропусков, судя по всему это отсуствие болкона.
# 	- Причины, по которым они могли возникнуть: Возможно кто-то указывает на сайте площадь балкон 0, а кто-то просто пропускает этот параметр. Поэтому при загрузке данных и получаеться такое количество пропусков, хотя этот параметр может быть важен для анализа.
# 	- Как исправлять: Заменить пропуски на 0. Так же в баг-репорте следует указать, что будет лучше если разработчики сделают так чтобы пропуски сразу обрабатывались как 0.
# 	- Финальный тип и почему: переведу в int, здесь только целые числа.

# %% [markdown]
# * Изменение

# %%
df["balcony"] = df["balcony"].fillna(0).astype('int')

# %%
df["balcony"].hist(bins=10)
plt.xlabel('Площадь балкона')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# #### 15. Обработка "locality_name"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["locality_name"])
# Out:
# Null or Na count is 49
# count               23650
# unique                364
# top       Санкт-Петербург
# freq                15721
# Name: locality_name, dtype: object

# %%
df['locality_name'].value_counts()
# Out:
# Санкт-Петербург                      15721
# посёлок Мурино                         522
# посёлок Шушары                         440
# Всеволожск                             398
# Пушкин                                 369
#                                      ...
# посёлок Ропша                            1
# деревня Курковицы                        1
# деревня Меньково                         1
# деревня Лупполово                        1
# садовое товарищество Приладожский        1
# Name: locality_name, Length: 364, dtype: int64

# %%
only_spb = df.query('locality_name == "Санкт-Петербург"')

# %%
only_spb['cityCenters_nearest'].value_counts().sort_index()
# Out:
# 181.00      1
# 208.00      1
# 215.00      1
# 287.00      1
# 291.00      1
#            ..
# 28644.00    2
# 28806.00    1
# 29263.00    1
# 29343.00    1
# 29493.00    1
# Name: cityCenters_nearest, Length: 6299, dtype: int64

# %% [markdown]
# * Вывод
# 	- Обнаруженные аномалии: Есть пропуски
# 	- Причины, по которым они могли возникнуть: Причины могут быть разные
#         - 1) Те кто выклыдывают обьявление в разделе Санкт-Петербург подумали, что Санкт-Петербург выставляеться автоматически.
#         - 2) Просто забыли указать свой город (каждый может ошибатся и забыться)
#         - 3) Возник какой-нибудь баг, к примеру название населенного пункта слишком длинное/короткое/непонятными_символами/ и тд. и система его не прочитала
# 	- Как исправлять: Можно было бы те города, которые от центра спб не дальше 29000 приписать к нему, но так как их очень мало, я просто заменю все пропуски на 'unknown', тогда,если понадобиться, то можно будет эту категории рассмотреть отдельно.

# %% [markdown]
# * Изменение

# %%
df['locality_name'] = df['locality_name'].fillna('unknown')

# %% [markdown]
# #### 16. Обработка "airports_nearest"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["airports_nearest"])
# Out:
# Null or Na count is 5542
# count    18157.00
# mean     28793.67
# std      12630.88
# min          0.00
# 25%      18585.00
# 50%      26726.00
# 75%      37273.00
# max      84869.00
# Name: airports_nearest, dtype: float64

# %%
df["airports_nearest"].value_counts().sort_index()
# Out:
# 0.00        1
# 6450.00     2
# 6914.00     1
# 6949.00     1
# 6989.00     6
#            ..
# 83758.00    1
# 84006.00    1
# 84665.00    1
# 84853.00    1
# 84869.00    1
# Name: airports_nearest, Length: 8275, dtype: int64

# %% [markdown]
# * Вывод
# 	- Обнаруженные аномалии: Есть пропуски. Так же странно наличе значения 0, кто-то здает квартиру прямо в аэропорту?
# 	- Причины, по которым они могли возникнуть: Этот параметр рассчитывала система Яндекса, вероятно для некоторых маленьких поселений аэропорт искался в определенном небольшом радиуси и при не нахождении такого создавался пропуск.
# 	- Как исправлять: строку с значением 0 удалю, здесь явно, что-то не так. Остальные пропуски оставлю как есть плюс стоит указать на это заказчику в баг-репорте.

# %% [markdown]
# * Изменение

# %%
df = df.loc[df["airports_nearest"]!=0]

# %% [markdown]
# #### 17. Обработка "cityCenters_nearest"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["cityCenters_nearest"])
# Out:
# Null or Na count is 5519
# count    18179.00
# mean     14190.80
# std       8608.39
# min        181.00
# 25%       9238.00
# 50%      13098.00
# 75%      16293.00
# max      65968.00
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# * Вывод
# 	- Обнаруженные аномалии: То же самое, что с растоянием до аэропорта - много пропусков.
# 	- Причины, по которым они могли возникнуть: те же.
# 	- Оставлю как есть

# %% [markdown]
# #### 18. Обработка "parks_around3000"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["parks_around3000"])
# Out:
# Null or Na count is 5518
# count    18180.00
# mean         0.61
# std          0.80
# min          0.00
# 25%          0.00
# 50%          0.00
# 75%          1.00
# max          3.00
# Name: parks_around3000, dtype: float64

# %%
df["parks_around3000"].hist()
plt.xlabel('Количество парков в пределах 3000')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# * Вывод
# 	- Обнаруженные аномалии: много пропусков, данные там просто не заполнены, поэтому трогать их не буду. Судя по количеству, причини теже что и с разделами выше.
# 	- Финальный тип и почему: заменю на int, потому что могут быть только целые числа.

# %%
df["parks_around3000"] = df["parks_around3000"].astype('Int64')

# %%
df["parks_around3000"].value_counts()
# Out:
# 0    10105
# 1     5681
# 2     1747
# 3      647
# Name: parks_around3000, dtype: Int64

# %% [markdown]
# #### 19. Обработка "parks_nearest"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["parks_nearest"])
# Out:
# Null or Na count is 15619
# count    8079.00
# mean      490.80
# std       342.32
# min         1.00
# 25%       288.00
# 50%       455.00
# 75%       612.00
# max      3190.00
# Name: parks_nearest, dtype: float64

# %% [markdown]
# * Вывод
# 	- Обнаруженные аномалии: так же много пропусков.
# 	- Причины, по которым они могли возникнуть: вероятно система не выгрузила эти данные.
# 	- Так как это не самые выжный показатель и заменять пропуски без искажения статистики не предоставляеться возможным, то я просто оставлю его как есть.

# %% [markdown]
# #### 20. Обработка "ponds_around3000"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["ponds_around3000"])
# Out:
# Null or Na count is 5518
# count    18180.00
# mean         0.77
# std          0.94
# min          0.00
# 25%          0.00
# 50%          1.00
# 75%          1.00
# max          3.00
# Name: ponds_around3000, dtype: float64

# %% [markdown]
# * Вывод
# 	- Здесь всё в точности как и с  parks_around3000. Пропуски не трогаю , тип поменяю на int.

# %% [markdown]
# * Изменение

# %%
df["ponds_around3000"] = df["ponds_around3000"].astype('Int64')

# %%
df["ponds_around3000"].value_counts()
# Out:
# 0    9070
# 1    5717
# 2    1892
# 3    1501
# Name: ponds_around3000, dtype: Int64

# %% [markdown]
# #### 21. Обработка "ponds_nearest"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["ponds_nearest"])
# Out:
# Null or Na count is 14588
# count    9110.00
# mean      517.98
# std       277.72
# min        13.00
# 25%       294.00
# 50%       502.00
# 75%       729.00
# max      1344.00
# Name: ponds_nearest, dtype: float64

# %% [markdown]
# * Вывод
# 	- Обнаруженные аномалии: здeсь всё понятно, там где NaN - значит прудов рядом нет, количество пропусков соответвует  "ponds_around3000" с значением 0.
# 	- Оставлю как есть.

# %% [markdown]
# * Изменение

# %% [markdown]
# #### 22. Обработка "days_exposition"

# %% [markdown]
# * Изучим значения

# %%
investigate_column(df["days_exposition"])
# Out:
# Null or Na count is 3181
# count    20517.00
# mean       180.89
# std        219.73
# min          1.00
# 25%         45.00
# 50%         95.00
# 75%        232.00
# max       1580.00
# Name: days_exposition, dtype: float64

# %%
df['days_exposition'] = df['days_exposition'].fillna(0).astype('int')

# %% [markdown]
# * Вывод
# 	- Обнаруженные аномалии: Есть много пропусков и так же незаполненые значения.
# 	- Причины, по которым они могли возникнуть: возможно сделка совершена, но на сайте не указали точную дату закрытия. Или же объевление было сразу снято, поэтому это аналог 0.
# 	- Как исправлять: заменю на 0 и затем создам отфильтрованную таблицу и смогу рассмотреть как старый df так и новый, после фильтрации. Сам столбец 'days_exposition' в любом случае придёться рассматривать без этого значения, потому что неизвестно что вызвало NaN (баг; снятие сделки сразу в первый день; сделка свершилась, но не указанна дата закрытия сделки или что-ли бо ещё.) Так же стоит указать на это в баг-репорте.
#     - Финальный тип: int.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
# Цена кв. метра
df['price_per_square_meter'] = df['last_price'] / df['total_area']

# %%
# День недели публикации
df['weekday'] = df['first_day_exposition'].dt.weekday

# %%
df['weekday'] = df['weekday'].map({0: '1 понедельник', 1: '2 вторник', 2: '3 среда', 3: '4 четверг', 
                    4: '5 пятница', 5: '6 суббота', 6: '7 воскресенье'})

# %%
# Месяц публикации
df['month'] = df['first_day_exposition'].dt.month

# %%
# Год
df['year'] = df['first_day_exposition'].dt.year

# %%
df[['weekday','month','year']]
# Out:
#              weekday  month  year
# 0          4 четверг      3  2019
# 1          2 вторник     12  2018
# 2          4 четверг      8  2015
# 3          5 пятница      7  2015
# 4          2 вторник      6  2018
# ...              ...    ...   ...
# 23694      2 вторник      3  2017
# 23695  1 понедельник      1  2018
# 23696  7 воскресенье      2  2018
# 23697      2 вторник      3  2017
# 23698      5 пятница      7  2017
#
# [23698 rows x 3 columns]

# %%
# Категаризация этажей
df['floor_category'] = np.where(df['floor'] == 1, 'первый', 'другой')
df['floor_category'] = np.where(df['floor'] == df['floors_total'], 'последний', df['floor_category'])

# %%
df['floor_category'].value_counts() # проверяю
# Out:
# другой       17445
# последний     3361
# первый        2892
# Name: floor_category, dtype: int64

# %%
# Добавляю столбец с отношением жилой площади и общей.
df['living_area_ratio'] = df['living_area'] / df['total_area']

# %%
# Добавляю столбец с отношением площади кухни и общей.
df['kitchen_area_ratio'] = df['kitchen_area'] / df['total_area']

# %%
#проверяю
df.describe().T
# Out:
#                            count        mean          std       min  \
# total_images            23698.00        9.86         5.68      0.00
# last_price              23698.00  6541529.43  10887242.57  12190.00
# total_area              23698.00       60.35        35.65     12.00
# rooms                   23698.00        2.07         1.08      0.00
# ceiling_height          14503.00        2.77         1.26      1.00
# floors_total            23612.00       10.67         6.60      1.00
# living_area             21795.00       34.46        22.03      2.00
# floor                   23698.00        5.89         4.89      1.00
# kitchen_area            21420.00       10.57         5.91      1.30
# balcony                 23698.00        0.59         0.96      0.00
# airports_nearest        18156.00    28795.26     12629.42   6450.00
# cityCenters_nearest     18179.00    14190.80      8608.39    181.00
# parks_around3000        18180.00        0.61         0.80      0.00
# ...

# %%
df.sample(8).T
# Out:
#                                           2818                 6331   \
# total_images                                 10                   10
# last_price                              2850000              3550000
# total_area                                42.00                39.50
# first_day_exposition        2017-11-08 00:00:00  2017-09-09 00:00:00
# rooms                                         1                    1
# ceiling_height                             3.00                 2.75
# floors_total                              15.00                11.00
# living_area                               18.00                18.10
# floor                                         4                    9
# is_apartment                              False                False
# studio                                    False                False
# open_plan                                 False                False
# kitchen_area                              10.00                11.30
# ...

# %% [markdown]
# Столбцы дабавлены, можно проводить исследование!

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Гистограммы значений total_area,  last_price, rooms и ceiling_height

# %% [markdown]
# #### Площадь

# %%
matplotlib.style.use('seaborn-pastel')

# %%
def boxplot(column):
    df.boxplot(column)
    plt.show()

# %%
# def simple_hist(column, bins):
#     df.plot(y = column, kind = 'hist', bins = bins, grid=True, figsize = (10,5))
#     plt.xlabel(column)
#     plt.ylabel('Количество объявлений')

# Пробовал создать функцию для упрощения, но с ceiling_height и last_price ведёт себя некорректно,
# когда задаю дополнительно значение xli

# %%
df.plot(title='Разбивка обьявлений по общей площади',y = 'total_area', kind = 'hist',color='lightgreen', bins = 100, grid=True, figsize = (8,8), range = (0,500),ec='black')
plt.xlabel('Площадь кв.м.')
plt.ylabel('Количество объявлений')
plt.show()

# %%
boxplot('total_area')

# %%
df.plot(title='Разбивка обьявлений по общей площади',y = 'total_area',color='lightgreen', kind = 'hist', bins = 100, grid=True, figsize = (8,8), range = (0,100),ec='black')
plt.xlabel('Площадь кв.м.')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# * Большинство квартир в диапозоне 25-65 кв.метров, так же много вариантов до 100кв., от 100 до 200 уже значительно меньше, а больше 200 уже совсем экслюзив. Вполне логичное распределение.

# %% [markdown]
# #### Стоимость квартиры

# %%
df['last_price_m'] = df['last_price']/1000000
df.plot(title='Разбивка обьявлений по стоимости квартиры млн',y = 'last_price_m', kind = 'hist',color='indianred', bins = 100, grid=True, figsize = (8,5),range=(0,80),ec='black')
plt.xlabel('Стоимость квартиры млн')
plt.ylabel('Количество объявлений')
plt.show()

# %%
boxplot('last_price_m')

# %%
df.plot(title='Разбивка обьявлений по стоимости квартиры млн', y = 'last_price_m', kind = 'hist',color='indianred', bins = 100, grid=True, figsize = (8,5),range=(0,15),ec='black')
plt.xlabel('Стоимость квартиры млн')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# * Большинство квартир стоят от 3 до 5 млн., так же много от 5 до 10 млн., и дальше чем дороже тем меньше.

# %% [markdown]
# #### Количество комнат

# %%
df.plot(title='Разбивка обьявлений по количеству комнат', y = 'rooms', kind = 'hist',color='orange', bins = 11, grid=True, figsize = (8,5),range=(0,10),ec='black')
plt.xlabel('Количество комнат')
plt.ylabel('Количество объявлений')
plt.show()

# %%
boxplot('rooms')

# %%
df.plot(title='Разбивка обьявлений по количеству комнат', y = 'rooms',kind = 'hist',color='orange', bins = 7, grid=True, figsize = (8,5),range=(0,6), ec='black')
plt.xlabel('Количество комнат')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# * Большинство квартир 1 и 2-х комнатные, чуть меньше 3-х комнатных, дальше начиная с 4-комнатных количество резко падает. Чем больше комнат тем меньше обьявлений - тоже вполне логично. Единственно  подозрительно наличие квартир с 0 комнатами.

# %%
df[df['rooms']==0].sample(8).T
# Out:
#                                       3874                 22521  \
# total_images                             13                    5
# last_price                          1700000              2350000
# total_area                            21.40                23.39
# first_day_exposition    2015-02-11 00:00:00  2018-08-28 00:00:00
# rooms                                     0                    0
# ceiling_height                         2.70                  NaN
# floors_total                           3.00                17.00
# living_area                             NaN                13.54
# floor                                     2                   13
# is_apartment                          False                False
# studio                                 True                 True
# open_plan                             False                False
# kitchen_area                            NaN                  NaN
# ...

# %% [markdown]
# * Судя по всему, большинство квартит с 0 комнатами это студии, тоже вполне логично.

# %% [markdown]
# #### Высота потолков

# %%
df.plot(title='Разбивка обьявлений по высоте потолка', y = 'ceiling_height', color='cornflowerblue' ,kind = 'hist', bins = 20, grid=True, figsize = (8,5),range=(0,10),ec='black')
plt.xlabel('Высота потолка')
plt.ylabel('Количество объявлений')
plt.show()

# %%
boxplot('ceiling_height')

# %%
df.plot(title='Разбивка обьявлений по высоте потолка', y = 'ceiling_height', color='cornflowerblue' , kind = 'hist', bins = 20, grid=True, figsize = (8,5),range=(2,5),ec='black')
plt.xlabel('Высота потолка')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# * В основном высота потолков - 2,5 метра. дальше чем выше - тем реже.

# %% [markdown]
# #### Вывод:
# -   * Все графики имееют распредление Пуссона, и для этого типа данных это вполне логично и соответсвует здравому смыслу.

# %% [markdown]
#  * В среднем стоимость квартир от 2 до 20 млн.
#  * Площадь от 20 до 200 кв.м.
#  * Количество комнат от 1 до 6
#  * Высота потолков 2,5 - 3 метра.

# %% [markdown]
# ### Исследование времени продажи квартиры

# %%
df['days_exposition'].describe()
# Out:
# count    23698.00
# mean       156.61
# std        213.55
# min          0.00
# 25%         22.00
# 50%         74.00
# 75%        199.00
# max       1580.00
# Name: days_exposition, dtype: float64

# %% [markdown]
# Среднее - 182 с половиной дня (ровно полгода)
#
#  Медиана - 96 дней (три месяца)

# %%
df['days_exposition'].hist(bins=80, color = 'darkturquoise',figsize=(10,5), ec='black')
plt.xlabel('Количество дней')
plt.ylabel('Количество объявлений')
plt.show()

# %%
boxplot('days_exposition')

# %%
df['days_exposition'].hist(bins=80, color = 'darkturquoise',figsize=(10,5), ec='black',range=(1,500))
plt.xlabel('Количество дней')
plt.ylabel('Количество объявлений')
plt.show()

# %%
df['days_exposition'].hist(bins=80, color = 'darkturquoise',figsize=(10,5), ec='black',range=(40,120),grid=True)
plt.xlabel('Количество дней')
plt.ylabel('Количество объявлений')
plt.show()

# %%
df['days_exposition'].hist(bins=80, color = 'darkturquoise',figsize=(10,5), ec='black',range=(1,40),grid=True)
plt.xlabel('Количество дней')
plt.ylabel('Количество объявлений')
plt.show()

# %%
# По-итогу понял как сделать функцию, хоть и в самом конце :) Переделывать не буду, но сохраню на будущее. 
def hist(df,column,bins,color,a,b,title):
    df[column].hist(bins=bins,
                   color=color,
                   figsize=(10,5),
                   ec='black',
                   range=(a,b))
    plt.xlabel(title)
    plt.ylabel('Количество объявлений')
    plt.show()

# %% [markdown]
# Видны выбросы на значениях 7,30,45,60,90,120. Кроме 7 и 45, все значения кратны 30 дням, т.е. месяцу. Вероятно каждые 30 дней  обьявления ЯндексНедвижимость снимаются автомотически. Я бы уточнил этот вопрос у заказчика.
#
# * Как подсказывает условия ЯндексНедвижимость каждые 30 дней нужно оплатить продление обьявлений, те кто не хотят продлевать снимают обьявления в эти дни / они снимаются автомотически при неоплате. Вероятно 45 дней тоже имеет такую же природу.

# %% [markdown]
# ### Удаление аномальных значений

# %% [markdown]
# #### Аномалии в days_exposition

# %%
g_df = df.query('days_exposition != 45 and days_exposition != 30 and days_exposition != 60 and days_exposition != 90 and days_exposition != 7 and days_exposition != 0 and days_exposition != 120').copy()

# %%
g_df.boxplot('days_exposition')
plt.ylim(0,800)
plt.show()

# %%
hist(g_df,'days_exposition',131,'darkturquoise',0,130,'Количество дней')

# %%
hist(g_df,'days_exposition',131,'darkturquoise',0,600,'Количество дней')

# %%
g_df['days_exposition'].describe()
# Out:
# count    18390.00
# mean       196.07
# std        227.11
# min          1.00
# 25%         44.00
# 50%        113.00
# 75%        259.00
# max       1580.00
# Name: days_exposition, dtype: float64

# %%
df['days_exposition'].describe()
# Out:
# count    23698.00
# mean       156.61
# std        213.55
# min          0.00
# 25%         22.00
# 50%         74.00
# 75%        199.00
# max       1580.00
# Name: days_exposition, dtype: float64

# %% [markdown]
# - Теперь среднее 196 дней
# - А Медиана 113 дня
# - Нормальные значения теперь распологаються от 1 до 600 (вместо 500 до обработки).
# - Дата фрайм сократился почти на 4000 строк (включая более 2000 бывших NaN).
# - Отброс выбросов очень больше  (20% df, это может исказить данные, поэтому для того чтобы рассмотрение всех остальных столбцов было более обьективным оставим все значения в 'days_exposition' как есть. Просто отметим, что часть значений в этом столбце возникла не из-за успешного закрытия сделки, а снятия обьявления.

# %% [markdown]
# #### Отфильтрую другие аномальные значения.

# %%
len(df[df['days_exposition']>730])
# Out:
# 750

# %% [markdown]
# Уберу значения  days_exposition больше 730, это обьявления которые весят более двух лет и причина неизвестна. Возможно квартира и вправду не продаёться, а может возник баг или их забыли закрыть на сайте. В любом случаее не использовать старые обьявления в выборке разумно по той причине, что цены постоянно меняються, и на сегодняшней день старая цена уже не так актуальна.

# %%
g_df2 = df.copy()

# %%
g_df2 = g_df2.query('days_exposition < 730')

# %%
g_df2.boxplot('days_exposition')
plt.show()

# %% [markdown]
# В "ceiling_height", "last_price"

# %%
g_df2["ceiling_height"]= g_df2["ceiling_height"].fillna(g_df2["ceiling_height"].mean()).mask(g_df2["ceiling_height"] > 9, g_df2["ceiling_height"].mean())

# %%
g_df2['ceiling_height'].value_counts().sort_index()
# Out:
# 1.00     1
# 1.20     1
# 1.75     1
# 2.00    11
# 2.20     1
#         ..
# 5.60     1
# 5.80     1
# 6.00     1
# 8.00     3
# 8.30     1
# Name: ceiling_height, Length: 169, dtype: int64

# %%
df.plot(title='Разбивка обьявлений по высоте потолка', y = 'ceiling_height', color='cornflowerblue' ,kind = 'hist', bins = 20, grid=True,range=(0,9), figsize = (8,5),ec='black')
plt.xlabel('Высота потолка')
plt.ylabel('Количество объявлений')
plt.show()

# %%
g_df2.boxplot('ceiling_height')
plt.show()

# %%
g_df2["last_price"]= g_df2["last_price"].mask(g_df2["last_price"] < 100000, g_df2["last_price"].mean())

# %%
g_df2["last_price_m"]= g_df2["last_price_m"].mask(g_df2["last_price_m"] < 0.1, g_df2["last_price_m"].mean())

# %%
1-(len(g_df2)/len(df))
# Out:
# 0.031690438011646505

# %% [markdown]
# Изначальные данные теряют 3,16% в результате фильтрации, вполне допустимо.

# %% [markdown]
# ### Зависимость цена квадратного метра от различных значений.

# %%
#g_df2.columns

# %%
sns.pairplot(g_df2,
             x_vars=["last_price", "last_price_m",'price_per_square_meter'],
             y_vars=["total_area",'living_area','balcony','kitchen_area','ceiling_height','total_images','rooms','floor'],
             hue='rooms',
             palette="rocket",
             height=6
             )

# %% [markdown]
# #### От общей площади квартиры.

# %%
def price_corr(column):
    print(g_df2[column].corr(g_df2['price_per_square_meter']))

# %%
def full_price_corr(column):
    print(g_df2[column].corr(g_df2['last_price']))

# %%
t_a_price = g_df2.groupby('total_area')['price_per_square_meter'].agg(['count','mean', 'median'])

# %%
t_a_price_p=g_df2.groupby('total_area')['last_price_m'].agg(['count','mean', 'median'])

# %%
t_a_price
# Out:
#             count       mean     median
# total_area
# 12.00           1  200000.00  200000.00
# 13.00           3  180769.23  142307.69
# 13.20           1  127727.27  127727.27
# 14.00           1   85000.00   85000.00
# 15.00           2  115000.00  115000.00
# ...           ...        ...        ...
# 590.00          1  110169.49  110169.49
# 618.00          1  485436.89  485436.89
# 631.00          1  221870.05  221870.05
# 631.20          1  221799.75  221799.75
# 900.00          1  466666.67  466666.67
#
# [2127 rows x 3 columns]

# %%
t_a_price_p
# Out:
#             count    mean  median
# total_area
# 12.00           1    2.40    2.40
# 13.00           3    2.35    1.85
# 13.20           1    1.69    1.69
# 14.00           1    1.19    1.19
# 15.00           2    1.73    1.73
# ...           ...     ...     ...
# 590.00          1   65.00   65.00
# 618.00          1  300.00  300.00
# 631.00          1  140.00  140.00
# 631.20          1  140.00  140.00
# 900.00          1  420.00  420.00
#
# [2127 rows x 3 columns]

# %%
t_a_price.plot(title='Зависимость стоимости кв. метра от площади',y = 'median', style = '.',alpha = 0.1,cmap='summer')
plt.xlabel('Общая площадь')
plt.ylabel('Стоимость кв. метра')
plt.ylim(0,800000)
plt.xlim(0,600)
plt.show()

# %%
t_a_price_p.plot(title='Зависимость стоимости квартиры от площади',y = 'median', style = '.',alpha = 0.1,cmap='summer')
plt.xlabel('Общая площадь')
plt.ylabel('Стоимость квартиры')
plt.ylim(0,200)
plt.xlim(0,600)
plt.show()

# %%
price_corr('total_area')
# Out:
# 0.2964947740600353

# %%
full_price_corr('total_area')
# Out:
# 0.6484595383555485

# %% [markdown]
# Зависимость очень слабая, чем выше площадь, тем дороже стоимость за кв. метр, но незначительно.
#
# Касаемо полной стоимости квартир, то корреляция вдвое больше и намного сильнее.

# %% [markdown]
# #### От числа комнат

# %%
rooms_price = g_df2.groupby('rooms')['price_per_square_meter'].agg(['count','mean', 'median'])

# %%
rooms_price
# Out:
#        count       mean     median
# rooms
# 0        194  108759.36  105918.83
# 1       7844  100691.45  100000.00
# 2       7707   95225.16   92757.31
# 3       5599   96850.43   88970.59
# 4       1115  110352.70   92666.67
# 5        304  126432.46   96384.26
# 6        101  139894.75   99642.31
# 7         58  164665.96  109996.07
# 8          9  173132.64  107333.33
# 9          7  105852.87   89035.61
# 10         3   98009.93   84372.71
# 11         1   95264.02   95264.02
# 12         1  466666.67  466666.67
# 14         2   92827.68   92827.68
# 15         1  110169.49  110169.49
# 19         1   86091.83   86091.83

# %%
rooms_price_p=g_df2.groupby('rooms')['last_price_m'].agg(['count','mean', 'median'])

# %%
rooms_price_p
# Out:
#        count    mean  median
# rooms
# 0        194    3.36    2.74
# 1       7844    3.83    3.60
# 2       7707    5.56    4.75
# 3       5599    8.10    6.20
# 4       1115   13.40    8.99
# 5        304   23.25   13.85
# 6        101   31.77   19.00
# 7         58   51.93   24.95
# 8          9   43.38   24.00
# 9          7   34.89   23.50
# 10         3   26.17   23.00
# 11         1   17.50   17.50
# 12         1  420.00  420.00
# 14         2   26.83   26.83
# 15         1   65.00   65.00
# 19         1   32.25   32.25

# %%
rooms_price.plot(y=['median','mean'],kind='bar',cmap='summer')
plt.title('Зависимость стоимости кв. метра от количества комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Стоимость кв. метра')
plt.xlim(0,7)
plt.ylim(80000,170000)
plt.show()

# %%
rooms_price_p.plot(y=['median','mean'],kind='bar',cmap='summer')
plt.title('Зависимость стоимости квартиры от количества комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Стоимость квартиры')
plt.xlim(0,7)
plt.ylim(0,40)
plt.show()

# %%
price_corr('rooms')
# Out:
# 0.052468892639844146

# %% [markdown]
# Касаемо кв. метра здесь присутсвует смешанная корреляция. От 0 до 3-х комнат цена за кв. м. по мере увелечения кол-ва комнат падает (обратная корреляция), а если больше 3-х комнат, то наоборот растёт (прямая корреляция). Так же как видно по графику, то для многокомнатных квартир (4 и более комнаты) свойствинен большой разброс цен за кв.м. (разница средней и медианы).
#
# Что касается стоимости квартир целиком, то корреляция прямая - чем больше комнат, тем дороже квартиры. Очень примечательна разница этих показателей.

# %% [markdown]
# #### От этажа

# %%
floor_price = g_df2.groupby('floor_category')['price_per_square_meter'].agg(['count','mean', 'median'])

# %%
floor_price
# Out:
#                 count       mean    median
# floor_category
# другой          16905  103190.18  98249.45
# первый           2795   82188.50  81333.33
# последний        3247   92897.40  87628.87

# %%
floor_price_p = g_df2.groupby('floor_category')['last_price_m'].agg(['count','mean', 'median'])

# %%
floor_price_p
# Out:
#                 count  mean  median
# floor_category
# другой          16905  6.58    4.80
# первый           2795  4.80    3.90
# последний        3247  7.28    4.30

# %%
floor_price.plot(y=['median','mean'],kind='bar',grid=True,cmap='cool',rot=45)
plt.title('Зависимость стоимости кв. метра от категории этажа')
plt.xlabel('Категория этажа')
plt.ylabel('Стоимость кв. метра')
plt.ylim(75000,110000)
plt.show()

# %%
floor_price_p.plot(y=['median','mean'],kind='bar',grid=True,cmap='cool',rot=45)
plt.title('Зависимость стоимости квартиры от категории этажа')
plt.xlabel('Категория этажа')
plt.ylabel('Стоимость квартиры')
plt.ylim(3)
plt.show()

# %% [markdown]
# Если посмотреть на медиану,то видно, что квартиры на первом этаже в среднем дешевле примерно на 10% чем квартиры на последнем. Квартиры из категории 'другой' оказались в среднем самими дорогими, но незначительно. (примерно на 5% дороже квартир на последнем этаже).
#
# Квартиры на последнем этаже имеют самый большой разброс цен.

# %% [markdown]
# #### От удалённости от центра

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
price_corr('cityCenters_nearest')
# Out:
# -0.3161904850958252

# %%
g_df2.plot(kind='scatter',x='cityCenters_nearest', y = 'price_per_square_meter', style = '.',alpha = 0.15,color='darkcyan',figsize=(12,6))
plt.title('Зависимость стоимости кв. метра от удалённости от центра')
plt.xlabel('Удалённость от центра в м.')
plt.ylabel('Стоимость кв. метра')
plt.ylim(0,1250000)
plt.show()

# %%
g_df2.plot(kind='scatter',x='cityCenters_nearest', y = 'last_price_m', style = '.',alpha = 0.15,color='darkcyan',figsize=(12,6))
plt.title('Зависимость полной стоимости квартиры от удалённости от центра')
plt.xlabel('Удалённость от центра в м.')
plt.ylabel('Стоимость квартиры в млн.')
plt.ylim(0,400)
plt.xlim()
plt.show()

# %% [markdown]
# Чем ближе к центру тем выше стоимость.

# %% [markdown]
# #### От дня недели, месяца, года.

# %%
day = g_df2.groupby('weekday')['price_per_square_meter'].agg(['count','mean', 'median'])

# %%
day
# Out:
#                count      mean    median
# weekday
# 1 понедельник   3501  99322.45  94696.97
# 2 вторник       4032  99409.56  95577.94
# 3 среда         3828  99445.39  95548.48
# 4 четверг       4151  99742.20  95000.00
# 5 пятница       3902  98688.25  94608.15
# 6 суббота       1884  99311.69  93920.92
# 7 воскресенье   1649  97238.27  94252.87

# %%
day_p=g_df2.groupby('weekday')['last_price_m'].agg(['count','mean', 'median'])

# %%
day.plot(y='median',kind='bar',grid=True,cmap='summer', rot=45)
plt.ylim(93000,96000)
plt.title('Зависимость стоимости кв. метра от дня недели')
plt.xlabel('День недели')
plt.ylabel('Стоимость кв. метра')

plt.show()

# %%
day_p.plot(y='median',kind='bar',grid=True,cmap='summer', rot=45)
plt.ylim(4.45,4.75)
plt.title('Зависимость полной стоимости квартиры от дня недели')
plt.xlabel('День недели')
plt.ylabel('Стоимость квартиры млн')

plt.show()

# %% [markdown]
# В целом разница в стоимости совсем небольшая (максимально 2%), но можно немного поразмышлять. )
#
# С вторника цена постепенно падает и дастигает самого низкого значения в субботу-воскресенье, потом снова растёт. Вероятно стоимость немного зависит от активности людей. В буднии дни активность растёт и цены выше. В пятницу же все хотят отдыхать и расслабляться, поэтому и цены ниже.

# %%
month =  g_df2.groupby('month')['price_per_square_meter'].agg(['count','mean', 'median'])

# %%
month_p =  g_df2.groupby('month')['last_price_m'].agg(['count','mean', 'median'])

# %%
month
# Out:
#        count       mean    median
# month
# 1       1453   99531.63  95263.16
# 2       2566   98708.37  95000.00
# 3       2476   98964.86  95672.98
# 4       2326  101908.64  96650.64
# 5       1230   98301.23  92857.14
# 6       1700   97693.24  92535.99
# 7       1641   99531.99  95000.00
# 8       1708   99955.64  96026.32
# 9       1910  100265.73  95509.22
# 10      2077   97434.26  93939.39
# 11      2312   98906.88  95459.97
# 12      1548   98324.70  93717.11

# %%
month_p
# Out:
#        count  mean  median
# month
# 1       1453  6.49    4.60
# 2       2566  6.44    4.65
# 3       2476  6.30    4.61
# 4       2326  6.69    4.80
# 5       1230  6.54    4.50
# 6       1700  6.28    4.40
# 7       1641  6.63    4.65
# 8       1708  6.29    4.55
# 9       1910  6.71    4.65
# 10      2077  6.18    4.55
# 11      2312  6.40    4.67
# 12      1548  6.75    4.64

# %%
month.plot(y='median',kind='bar',grid=True,color='skyblue',rot=0,figsize=(8,6))
plt.ylim(92000,98000)
plt.title('Зависимость стоимости кв. метра от месяца')
plt.xlabel('Месяц')
plt.ylabel('Стоимость кв. метра')
plt.show()

# %%
month_p.plot(y='median',kind='bar',grid=True,color='skyblue',rot=0,figsize=(8,6))
plt.ylim(4.2)
plt.title('Зависимость полной стоимости квартиры от месяца')
plt.xlabel('Месяц')
plt.ylabel('Стоимость квартиры млн.')
plt.show()

# %% [markdown]
# Самые высокие цены оказываються в апреле, в августе,сентяре. Самые низкие перед сезоном отпусков в мае и июне. Макисмальный разброс не более 5%.
#
# Вероятно люди хотят совершить сделки перед сезоном отпусков, поэтому больше всего обьявлений и самые высокие цены в начале весны и зимой, чтобы можно было успеть заключить сделку и спокойно ехать отдыхать.)
#
# Цена растёт с нового года вплоть до апреля, затем в мая резко падает, к июня достигается минимум. Затем вновь растёт вплоть до сентября и затем уже падает к новому году.

# %%
year =  g_df2.groupby('year')['price_per_square_meter'].agg(['count','mean', 'median'])

# %%
year_p = g_df2.groupby('year')['last_price_m'].agg(['count','mean', 'median'])

# %%
year
# Out:
#       count       mean     median
# year
# 2014     62  120466.55  113774.24
# 2015    793  105481.87   92063.49
# 2016   2525   97444.27   91463.41
# 2017   8170   97610.93   92565.09
# 2018   8518   97761.35   95688.49
# 2019   2879  107123.78  103305.79

# %%
year_p
# Out:
#       count   mean  median
# year
# 2014     62  12.77    8.79
# 2015    793   8.72    5.15
# 2016   2525   6.60    4.50
# 2017   8170   6.58    4.50
# 2018   8518   5.95    4.55
# 2019   2879   6.78    5.05

# %%
year.plot(y='median',kind='bar',grid=True,cmap='ocean',rot=45)
plt.ylim(85000,120000)
plt.title('Зависимость стоимости кв. метра от года')
plt.xlabel('Год')
plt.ylabel('Стоимость кв. метра')
plt.show()

# %%
year_p.plot(y='median',kind='bar',grid=True,cmap='ocean',rot=45)
plt.ylim(4)
plt.title('Зависимость полной стоимости квартиры')
plt.xlabel('Год')
plt.ylabel('Стоимость квартиры млн.')
plt.show()

# %%
g_df2.query('year==2014').groupby('month')['price_per_square_meter'].agg(['count','mean', 'median'])
# Out:
#        count       mean     median
# month
# 11         9  134734.73  134200.00
# 12        53  118043.65  108974.36

# %% [markdown]
# В целом стоимость кв.м. расёт с 2016 г.
#
# В 2014 году есть всего два месяца, и там всего 53 объявления, вероятно  высокая стоимость вызвана  событиями произошедшими в 2014 году, но 53 объявления это слишком мало для достоверного анализа. )
#
# Плоная стоимость квартиры же наоборот с 2016-2018г. практически стоит на месте и идёт в рост с 2019.

# %% [markdown]
# ### Исследование населённых пунктов

# %%
city = g_df2.groupby('locality_name')['price_per_square_meter'].agg(['count', 'median'])

# %%
print('10 городов  с наибольшим количеством обьявлений.')
city.sort_values('count', ascending = False).head(10)
# Out:
# 10 городов  с наибольшим количеством обьявлений.
#                    count     median
# locality_name
# Санкт-Петербург    15202  104687.50
# посёлок Мурино       504   85878.46
# посёлок Шушары       429   76923.08
# Всеволожск           386   65789.47
# Пушкин               354  100000.00
# Колпино              332   74562.81
# посёлок Парголово    320   91387.36
# Гатчина              293   67695.96
# деревня Кудрово      280   91831.87
# Выборг               229   58158.32

# %%
city.query('count>50')['count'].plot(kind='pie',figsize=(15,15), label='', autopct='%1.0f%%')
plt.title('Процент обьявлений по городам')
plt.show()

# %% [markdown]
# 73% всей выборки берёт на себя Санкт-Петербург, остальные посёлки входящие в топ-10 занимают от 0,5 до 3% от всей выборки.

# %%
print('10 городов с самой высокой стоимостью жилья.')
city.sort_values('median', ascending = False).query('count >=100').head(10)
# Out:
# 10 городов с самой высокой стоимостью жилья.
#                    count     median
# locality_name
# Санкт-Петербург    15202  104687.50
# Пушкин               354  100000.00
# Кудрово              172  100000.00
# Сестрорецк           177   99916.67
# деревня Кудрово      280   91831.87
# посёлок Парголово    320   91387.36
# посёлок Мурино       504   85878.46
# Петергоф             190   82182.54
# посёлок Шушары       429   76923.08
# Колпино              332   74562.81

# %% [markdown]
# Если не считать выбросы, то самым дорогим выходит так же Санкт-Петербург, если исключить города в которых было меньше 100 обьявлений, то следующими идут Пушкин,Кудрово, Сестрорецк, Парголово.
#
# Видко кстати что Кудрово записывают по разному.
#
# Далее я везьде беру выборку от 100 обьявлений, чтобы исключить маленькие поселения.

# %%
print('10 городов с самой низкой стоимостью жилья.')
city.sort_values('median').head(10)
# Out:
# 10 городов с самой низкой стоимостью жилья.
#                          count    median
# locality_name
# деревня Старополье           3  11000.00
# посёлок станции Свирь        2  11481.48
# деревня Вахнова Кара         1  11688.31
# деревня Выскатка             2  12335.48
# поселок Совхозный            2  12629.13
# деревня Малая Романовка      1  12724.55
# поселок Тёсово-4             1  12931.03
# деревня Сижно                1  13709.68
# деревня Ям-Тесово            2  13711.55
# поселок Житково              2  14956.28

# %%
print('10 городов с самой низкой стоимостью жилья.')
city.query('count>=100').sort_values('median').head(10)
# Out:
# 10 городов с самой низкой стоимостью жилья.
#                count    median
# locality_name
# Сланцы           109  18240.34
# Волхов           110  35071.88
# Кириши           124  37981.48
# Кингисепп        104  46770.83
# Тосно            103  58000.00
# Выборг           229  58158.32
# Всеволожск       386  65789.47
# Сертолово        138  67588.24
# Гатчина          293  67695.96
# Красное Село     175  71875.00

# %% [markdown]
# Среди самых дешёвых вариантов оказываються поселения с крайне низким количеством обьявлений (вероятно как и населения :))
#
# Если взять варианты в  которых больше 100 обьявлений, то в топе самых бюджетных оказываються: Сланцы, Волхов, Кириши, Кингисепп, Тосно, Выборг, Всеволжск.

# %% [markdown]
# #### Сравним значения с исходными данными (без фильтрации по дате).

# %%
print('10 городов  с наибольшим количеством обьявлений.')
df.groupby('locality_name')['price_per_square_meter'].agg(['count', 'median']).sort_values('count', ascending = False).head(10)
# Out:
# 10 городов  с наибольшим количеством обьявлений.
#                    count     median
# locality_name
# Санкт-Петербург    15720  104761.90
# посёлок Мурино       522   85878.46
# посёлок Шушары       440   76876.17
# Всеволожск           398   65789.47
# Пушкин               369  100000.00
# Колпино              338   74723.75
# посёлок Парголово    327   91642.86
# Гатчина              307   67796.61
# деревня Кудрово      299   91860.47
# Выборг               237   58158.32

# %% [markdown]
# Здесь примерно похожая картина

# %%
print('10 городов с самой высокой стоимостью жилья.')
df.groupby('locality_name')['price_per_square_meter'].agg(['count', 'median']).query('count >=100').sort_values('median', ascending = False).head(10)
# Out:
# 10 городов с самой высокой стоимостью жилья.
#                    count     median
# locality_name
# Санкт-Петербург    15720  104761.90
# Пушкин               369  100000.00
# Кудрово              173  100000.00
# Сестрорецк           183   99678.46
# деревня Кудрово      299   91860.47
# посёлок Парголово    327   91642.86
# посёлок Мурино       522   85878.46
# Петергоф             201   82142.86
# посёлок Шушары       440   76876.17
# Колпино              338   74723.75

# %%
print('10 городов  с самой низкой стоимостью жилья.')
df.groupby('locality_name')['price_per_square_meter'].agg(['count', 'median']).sort_values('median').query('count >=100').head(10)
# Out:
# 10 городов  с самой низкой стоимостью жилья.
#                count    median
# locality_name
# Сланцы           112  18254.79
# Волхов           111  35000.00
# Кириши           125  37962.96
# Кингисепп        104  46770.83
# Тосно            104  58016.06
# Выборг           237  58158.32
# Всеволожск       398  65789.47
# Сертолово        142  67588.24
# Гатчина          307  67796.61
# Красное Село     178  71786.04

# %% [markdown]
# - Больше всего обьявлений в Санкт-Петербурге.
# - Самые дорогое жильё в Санкт-Петербурге, Пушкине, Сестрорецке и п. Парголово.
# - Самое бюджетное жильё в населённых пунктах: Сланцы, Волхов, Кириши, Кингисепп, Тосно, Выборг, Всеволжск.

# %% [markdown]
# ### Зависимость Стоимости жилья в Санкт-Петербурге от расстояния до центра.

# %%
df['cityCenters_nearest_km'] = df['cityCenters_nearest']/1000
df['cityCenters_nearest_km'] = df['cityCenters_nearest_km'].fillna(999999).astype('int')
ccn_km = df.query('locality_name == "Санкт-Петербург" and cityCenters_nearest_km !=999999').groupby('cityCenters_nearest_km')['price_per_square_meter'].agg(['median','mean','count'])
ccn_km.plot(y=['median','mean'])
ccn_km
# Out:
#                            median       mean  count
# cityCenters_nearest_km
# 0                       138536.99  187324.13     86
# 1                       123966.94  166603.76    240
# 2                       116363.64  146662.86    307
# 3                       110080.01  129416.34    526
# 4                       126086.96  137475.50    907
# 5                       126041.67  146979.23    769
# 6                       134117.30  152277.89    470
# 7                       125000.00  141399.73    407
# 8                       114137.69  120581.35    670
# 9                       105317.63  110012.55    690
# 10                      105656.22  111641.29    912
# 11                      103225.81  106790.88   1415
# 12                      103921.57  108295.77   1515
# 13                      104296.11  107209.14   1402
# 14                      102473.48  104986.48   1512
# 15                       98571.43  101883.12   1373
# 16                       97727.27  100085.60   1106
# ...

# %% [markdown]
# Я не питерец, но расскажу, что вижу на графике. ;) Есть две примечательные зоны, которые можно назвать центральными.
# - от 0 до 3 км.(цена падает вниз) и от 3 до 6 км. (цена снова растёт)
# - после 6 километров стоимость идёт вниз.
# - судя по графику после 25 км. начинаються населённые пункты прилегающие к городу или входящие в его состав.

# %% [markdown]
# И того я бы выделил 4 зоны:
# * 0-6 км.   -  Центр
# * 6-17 км.  -  Город
# * 17-25 км. - Окраина
# * 25+ км.   - Прилегющие пгт.

# %% [markdown]
# ### Центр Санкт-Петербурга

# %%
spb_center = df.query('cityCenters_nearest_km <= 6 and locality_name == "Санкт-Петербург"')

# %% [markdown]
# Сравним матрицу корреляции всей выборки и только центра Санкт-Петербурга.

# %%
plt.figure(figsize=(6,12))
sns.heatmap(g_df2[["total_area",'living_area','balcony','kitchen_area','ceiling_height','total_images','rooms','floor','last_price','price_per_square_meter']].corr()[['last_price','price_per_square_meter']].sort_values(by='last_price', ascending=False), annot=True, cmap="copper", fmt='.2f')
plt.title('Корреляция - Вся выборка')
plt.show()

# %%
plt.figure(figsize=(6,12))
sns.heatmap(spb_center[["total_area",'living_area','balcony','kitchen_area','ceiling_height','total_images','rooms','floor','last_price','price_per_square_meter']].corr()[['last_price','price_per_square_meter']].sort_values(by='last_price', ascending=False), annot=True, cmap="copper", fmt='.2f')
plt.title('Корреляция - Центр Санкт-Петербурга')
plt.show()

# %%
print('Медийная стоймость квартир во всей выборке:',g_df2['last_price_m'].median())
print('Медийная стоймость квартир в Санкт-Петерурге:',g_df2.query('locality_name == "Санкт-Петербург"')['last_price_m'].median())
print('Медийная стоймость квартир в центре Санкт-Петербурга:',spb_center['last_price_m'].median())
print('Медийная стоймость квартир в области:',g_df2.query('locality_name != "Санкт-Петербург"')['last_price_m'].median())
print('')

print('Медийная стоймость кв.м. во всей выборке:',g_df2['price_per_square_meter'].median())
print('Медийная стоймость кв.м. в Санкт-Петерурге:',g_df2.query('locality_name == "Санкт-Петербург"')['price_per_square_meter'].median())
print('Медийная стоймость кв.м. в центре Санкт-Петербурга:',spb_center['price_per_square_meter'].median())
print('Медийная стоймость кв.м. в области:',g_df2.query('locality_name != "Санкт-Петербург"')['price_per_square_meter'].median())
print('')
# Out:
# Медийная стоймость квартир во всей выборке: 4.6
# Медийная стоймость квартир в Санкт-Петерурге: 5.5
# Медийная стоймость квартир в центре Санкт-Петербурга: 9.3
# Медийная стоймость квартир в области: 3.185
#
# Медийная стоймость кв.м. во всей выборке: 95000.0
# Медийная стоймость кв.м. в Санкт-Петерурге: 104687.5
# Медийная стоймость кв.м. в центре Санкт-Петербурга: 123529.41176470589
# Медийная стоймость кв.м. в области: 68800.0

# %% [markdown]
# - Квартиры в центре стоят в среднем в три раза дороже чем в области, в полтора раза дороже городсих квартир и вдое дороже показателя всей выборке
# - в стоимости квадратного метра разброс не тако сильный но все равно есть.

# %%
g_df2.query('locality_name == "Санкт-Петербург"')['price_per_square_meter'].median()
# Out:
# 104687.5

# %% [markdown]
# В целом корреляции довольно низкие в обоих матрицах. Единственное что выделяется зависимоть цены от общей площади, площади кухни и площади жилой зоны. Так же интересное наблюдение в обоих выборках стоимость всей квартиры коррелирует с общей и жилой площадью вдое больше чем цена за квадратный метр. Тоже самое касается количества комнат, полная стоимость квартиры имеет низкую корреляцию (0.31-0.37), а цена квадратного метра не коррелирует вовсе.
#
# - Ниже рассмотрим зависимости цены от разных факторов с помощью графиков.

# %% [markdown]
# #### Зависимость от количества комнат.

# %%
spb_center_rooms = spb_center.groupby('rooms')['price_per_square_meter'].agg(['median','mean','count'])

print(spb_center['rooms'].corr(spb_center['price_per_square_meter']))

spb_center_rooms.query('count>50').plot(kind='bar',title='Квадратный метр',y = ['median','mean'],grid=True)
plt.xlabel('Количество комнат')
plt.ylabel('Стоимость квадратного метра')
plt.show()
# Out:
# -0.00983933850556457

# %%
print(spb_center['rooms'].corr(spb_center['last_price']))

spb_center.groupby('rooms')['last_price_m'].agg(['median','mean','count']).query('count>50').plot(kind='bar',title='Стоимость квартиры',y = ['median','mean'],grid=True)
plt.xlabel('Количество комнат')
plt.ylabel('Стоимость квартиры млн.')
plt.show()
# Out:
# 0.3098733910278382

# %% [markdown]
# Корреляция очень низкая, если смотреть на медиану, то чем больше комнат, тем ниже цена кв.метра, но выше стоимость квартиры. Если смотреть на среднее и сравнить с медианой, то чем больше комнат, тем больше разброс цен.

# %% [markdown]
# #### Зависимость от этажа

# %%
spb_center.groupby('floor_category')['price_per_square_meter'].agg(['median','mean']).plot(title='Квадратный метр',kind='barh',y = ['median','mean'],figsize=(8,6))

spb_center.groupby('floor_category')['last_price_m'].agg(['median','mean']).plot(title='Стоимость квартиры по этажам',kind='barh',y = ['median','mean'],figsize=(8,6))
plt.show()

# %% [markdown]
# Зависимоть низкая. Но квартиры на первом этаже в среднем оказываются самыми дешёвыми.

# %% [markdown]
# #### Зависимость от удаленности от центра.

# %%
spb_center.groupby('cityCenters_nearest_km')['price_per_square_meter'].agg(['median','mean','count']).plot(title='Квадратный метр по удалённости от центра',kind='bar',y = ['median','mean'],cmap='cividis',rot=0)

spb_center['cityCenters_nearest'].corr(spb_center['price_per_square_meter'])
plt.xlabel('Удалённость от центра км.')
plt.ylabel('Стоимость квадратного метра')
plt.show()

# %%
spb_center.groupby('cityCenters_nearest_km')['last_price_m'].agg(['median','mean','count']).plot(title='Стоимость квартиры по удалённости от центра',kind='bar',y = ['median','mean'],cmap='cividis',rot=0)

spb_center['cityCenters_nearest'].corr(spb_center['last_price_m'])
plt.xlabel('Удалённость от центра км.')
plt.ylabel('Стоимость квартиры')
plt.show()

# %% [markdown]
# Есть низкая обратная корреляция. От центра до 3го км - стоимость кв. метра немного снижается, с 3го начинает расти.
#
# С стоимостью квартиры обратная корреляция более сильная - видно как цена в целом падает и 6й км. оказывается так же самым дешёвым как и 3й.
#
# Так же видно, что чем ближе к самому центру (0-й км.) тем более высокий разброс цен в этой области (разница средней и медианы)

# %% [markdown]
# #### Зависимость от дня недели

# %%
spb_center.groupby('weekday')['price_per_square_meter'].agg(['median','mean','count']).plot(title='Квадратный метр по дням недели',kind='bar',y = ['median','mean'],cmap='copper',rot=45)
plt.ylim(90000,160000)
plt.xlabel('День недели')
plt.ylabel('Стоимость квадратного метра')
spb_center.groupby('weekday')['price_per_square_meter'].agg(['median','mean','count'])
# Out:
#                   median       mean  count
# weekday
# 1 понедельник  126325.42  144265.45    510
# 2 вторник      118748.32  142527.92    554
# 3 среда        124586.75  142758.58    586
# 4 четверг      120578.78  145014.66    681
# 5 пятница      125000.00  143627.06    557
# 6 суббота      128703.70  155972.25    237
# 7 воскресенье  129279.68  147600.73    180

# %%
spb_center.groupby('weekday')['last_price_m'].agg(['median','mean','count']).plot(title='Стоимость квартиры по дням недели',kind='bar',y = ['median','mean'], cmap='copper',rot=45)
spb_center.groupby('weekday')['last_price_m'].agg(['median','mean','count'])
plt.xlabel('День недели')
plt.ylabel('Стоимость квартиры млн.')
plt.ylim(7.5)
plt.show()

# %% [markdown]
# Здесь есть явное различие с основной выборкой. Во вторник стоимость наоборот меньше всего и затем растёт до конца недели и самая высокая цена получаеться в воскресенье и понедельник. В субботу выставляються обьявления с большим разбросом цен.

# %% [markdown]
# #### Зависимость от месяца

# %%
spb_center.groupby('month')['price_per_square_meter'].agg(['median','mean','count']).plot(title='Квадратный метр по месяцам',kind='bar',y = ['median','mean'],figsize=(12,6),rot=0,cmap='viridis').yaxis.grid(True)
plt.ylim(110000,160000)
plt.xlabel('Месяц')
plt.ylabel('Стоимость квадратного метра')
spb_center.groupby('month')['price_per_square_meter'].agg(['median','mean','count'])
# Out:
#           median       mean  count
# month
# 1      129334.85  147892.19    204
# 2      121285.19  144605.62    366
# 3      130333.33  147665.88    351
# 4      127574.16  156002.52    311
# 5      122077.92  135036.53    183
# 6      117086.21  135257.25    262
# 7      118236.58  141620.85    266
# 8      125000.00  146001.17    239
# 9      124052.44  146258.62    288
# 10     123498.00  140581.07    271
# 11     123333.33  142519.67    333
# 12     121328.22  149976.20    231

# %%
spb_center.groupby('month')['last_price_m'].agg(['median','mean','count']).plot(title='Стоимость квартиры по месяцам',kind='bar',y = ['median','mean'],figsize=(12,6),cmap='viridis',rot=0).yaxis.grid(True)
plt.ylim()
plt.xlabel('Месяц')
plt.ylabel('Стоимость квартиры млн.')
spb_center.groupby('month')['last_price_m'].agg(['median','mean','count'])
# Out:
#        median   mean  count
# month
# 1       10.35  16.53    204
# 2        9.51  15.42    366
# 3        9.49  14.88    351
# 4        9.30  16.39    311
# 5        8.98  13.92    183
# 6        8.60  13.09    262
# 7        9.25  14.91    266
# 8        8.97  14.04    239
# 9        9.93  15.97    288
# 10       8.70  13.65    271
# 11       9.59  14.46    333
# 12       8.80  16.10    231

# %% [markdown]
# Здесь тоже есть отличе.
# - Самые дорогие квартиры в январе и сентябре. Самые дешёвые в декабре и июне.
# - По стоимости кв. метра дороже всего выставляют в январе, марте, апреле. Дешевле всего в июне и июле.
# - В отличии от основой выборки, где декабрь был самым сильным месяцем с высокими ценами, здесь лидирует январь.
# - В основной выборке саме низкие цены в мая, а здесь в июне.

# %% [markdown]
# #### Зависимость от года

# %%
spb_center.groupby('year')['price_per_square_meter'].agg(['median','mean','count']).plot(title='Квадратный метр по годам',kind='bar',y = ['median','mean'],figsize=(12,6),cmap='Set3',rot=45).yaxis.grid(True)
plt.ylim(110000)
plt.xlabel('Год')
plt.ylabel('Стоимость квадратного метра')
spb_center.groupby('year')['price_per_square_meter'].agg(['median','mean','count'])
# Out:
#          median       mean  count
# year
# 2014  143465.55  195654.46     27
# 2015  119568.11  147424.79    297
# 2016  116784.84  138241.45    455
# 2017  121260.86  143165.40   1180
# 2018  124875.00  141078.34    990
# 2019  136305.21  162670.70    356

# %%
spb_center.groupby('year')['last_price_m'].agg(['median','mean','count']).plot(title='Стоимость квартиры по годам',kind='bar',y = ['median','mean'],figsize=(12,6),cmap='Set3',rot=45).yaxis.grid(True)
plt.ylim(7)
plt.xlabel('Год')
plt.ylabel('Стоимость квартиры млн.')
spb_center.groupby('year')['last_price_m'].agg(['median','mean','count'])
# Out:
#       median   mean  count
# year
# 2014   19.80  25.69     27
# 2015   10.50  17.69    297
# 2016    9.40  14.86    455
# 2017    9.12  15.44   1180
# 2018    8.93  12.97    990
# 2019    9.95  16.03    356

# %% [markdown]
# * Картина схожа с основной выборкой с 2016г. кв. метр растёт в цене.
# * Стоит отметить, что цена в Санкт-Петербурге выше чем в основной выборке примерно на 20-25% год к году.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Сильнее всего стоимость квартиры зависит от:**
# - Стоиомсти квадратного метра.
# - Общей площади
# - Жилой площади
# - Площади кухни
# - Количества комнат
# - Удалённости от центра
#
#
# * При этом стоимость квадратного метра коррелируют с этими параметрами вдвое меньше.
#
#
# **Остальные параметры имеют меньший вес, но тоже немного влияют на стоимость. К ним относяться:**
# - Этаж
# - День и Месяц размещения
#
# **Рассмотрим подробнее каждый пункт:**
#
# - Стоиомость квадратного метра. Чем выше - тем дороже квартира.
# - Чем больше общая площадь, тем дороже квартира.
# - Чем больше жилая площать, тем дороже квартира.
# - Чем больше площадь кухни, тем дороже квартира
# - Чем больше комнат, тем дороже квартира. Но стоимость кв. метра наоборот дешевеет у 2 и 3- комнатных квартир, затем чем больше комнат тем дороже.
# - Чем дальше квартира от центра, тем дешевле, но и меньше разброс цен.
# - Квартиры на первом этаже оказываються дешевле прочих.
# - В будние дни люди выставляют более дорогие квартиры, чем в выходные.
# - В летние месяцы количество обьявлений меньше и квартиры стоят дешевле, так же самыми дешёвыми месяцем выходит Май и Июнь. Зимние месяцы как и начало весны выходят самыми дорогими, так же там выставляют больше всего обьявлений, исключение составлят декабрь, перед новым годом так стоимость падает.
# - С 2016 г. стоимость квадратного метра растёт год к году.
# - Стоимость квартир падала с 2014-2016, 2016-2018 практически не менялась, с 2019 пошла в рост.
# - - Квартиры в центре стоят в среднем в три раза дороже чем в области, в полтора раза дороже городсих квартир и вдое дороже показателя всей выборке. В стоимости квадратного метра разброс не тако сильный но все равно есть.
# - Стоимость квартир в центре имеет схожее поведение, но всё-так с некоторыми отличиями. К примеру различается динамика дней недели, самый низкий постоимости вторник, а потом цена растёт вплоть до воскресенья и понедельника.
#
# **В завершении**
#
# *Стоит отметить, что мы рассматривали рынок недвижимости в целом, без раделения на категории и сегметы. Вероятно если рассматривать каждый сегмент в отдельности мы сможем заметить различия с поведением рынка в целом, так же как видим разницу между недвижимостью в центре Санкт-Петербурга и всей выборкой в целом.*
